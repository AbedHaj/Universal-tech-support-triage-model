# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyBJX0dBcfEysCReURlt3SVBI72RxNN3IHc")

# %%
model = genai.GenerativeModel("gemma-3-12b-it")

# %%
prompt = """You are generating synthetic customer support tickets for a B2B e-commerce platform.

TASK:
Generate exactly 10 independent support tickets.

Each ticket must include:
1. ticket_text: a realistic, natural-language description of a technical problem
2. user_metadata: structured information about the sender


ISSUE CATEGORIES (use ONLY these):
- payment_failure
- checkout_validation_error
- inventory_visibility
- account_access
- website_bug

REQUIREMENTS:
- Tickets must sound like real users (imperfect grammar allowed).
- Vary writing style, length, and tone.
- Match the label correctly to the ticket_text.
- Do NOT mention the label inside the ticket_text.
- Keep user_metadata realistic and consistent with the issue (if a person is a novice make that reflect in the ticket, if he is an expert let it also reflect).

USER METADATA SCHEMA:
- Position in company
- Degree of expertise (Novice, Intermediate, Expert)

OUTPUT FORMAT:
Return a JSON array of 10 objects.
Each object must follow this schema exactly:

{
  "ticket_text": "...",
  "user_metadata": "Position", "Degree of expertise (Novice, intermedite, expert)",
  "affected component": "...",
  "severity": "how severe is the problem (low, medium, high)"
}"""

# %%
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# ```json
# [
#   {
#     "ticket_text": "Hi, we tried to place an order for 500 widgets this morning, and the payment keeps getting declined. We're using our company card, and it's definitely got enough credit.  Tried a couple of times now.  Any ideas?",
#     "user_metadata": "Purchasing Manager, Intermediate",
#     "affected component": "Payment Gateway",
#     "severity": "high"
#   },
#   {
#     "ticket_text": "The checkout process is giving me a weird error. It says 'Invalid Quantity' even though I'm only ordering 10 of the blue bolts. I've tried different browsers too, same problem.  Really frustrating!",
#     "user_metadata": "Engineer, Expert",
#     "affected component": "Checkout Process",
#     "severity": "medium"
#   },
#   {
#     "ticket_text": "Our website is showing that the 'SuperGrip Handles' are in stock, but when we try to order 20, it says 'Out of Stock'. This has happened with a few other items too.  Is there a delay in updating the inventory?",
# ...
