# %%
import google.generativeai as genai
import pandas as pd



genai.configure(api_key="")

model = genai.GenerativeModel("gemma-3-12b-it")

# %%
import json
import re

# %%
prompt = """You are generating a structured ontology for enterprise information systems.
This ontology will be used later to generate synthetic customer support tickets.

TASK:
Generate a hierarchical JSON structure with the following levels:

1. 5 domains (e.g., E-commerce, Healthcare IT, Finance Systems, Telecom, etc.)
2. For each domain, generate exactly 1 realistic companies operating in that domain.
3. For each company, generate exactly 1 core business workflows.
4. For each workflow, generate exactly 2 technical components, and give realistic workflow Description for each of them

REQUIREMENTS:
- All entities must be realistic and enterprise-oriented.
- Company names should sound real but be fictional.
- Workflows should reflect actual business processes.
- Components should be technical or system-level (not people).
- Issues must be specific, actionable, and suitable for support tickets.
- Keep terminology consistent across the hierarchy.
- Do NOT generate ticket text.
- Do NOT include explanations or commentary.

OUTPUT FORMAT:
Return a single valid JSON object with the following schema:

{
  "Domain Name": {
    "companies": {
      "Company Name": {
        "workflows": {
          "Workflow Name", "Workflow Description: {
            "components": {
              "Component Name"
            }
          }
        }
      }
    }
  }
}

IMPORTANT:
- Generate exactly the requested counts at every level.
- Output must be valid JSON."""

# %%
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# ```json
# {
#   "E-commerce": {
#     "companies": {
#       "NovaRetail Group": {
#         "workflows": {
#           "Order Fulfillment": {
#             "Description": "Automated process for receiving, processing, and shipping customer orders.",
#             "components": {
#               "Inventory Management System": {},
#               "Shipping Logistics API": {}
#             }
#           },
#           "Returns Processing": {
#             "Description": "Handles customer returns, including authorization, inspection, and refund/exchange.",
#             "components": {
#               "Return Authorization Portal": {},
#               "Warehouse Management System": {}
#             }
#           }
#         }
#       }
#     }
#   },
#   "Healthcare IT": {
#     "companies": {
#       "Apex Health Systems": {
#         "workflows": {
#           "Patient Appointment Scheduling": {
#             "Description": "Manages patient appointment booking, reminders, and rescheduling.",
#             "components": {
#               "Electronic Health Record (EHR) Integration": {},
#               "Appointment Scheduling Engine": {}
#             }
#           },
#           "Medical Image Storage & Retrieval": {
#             "Description": "Securely stores and provides access to medical images (X-rays, MRIs, etc.).",
#             "components": {
#               "PACS (Picture Archiving and Communication System)": {},
#               "Image Viewing Workstation": {}
#             }
#           }
#         }
#       }
#     }
#   },
#   "Finance Systems": {
#     "companies": {
#       "Veridian Financial Corp": {
#         "workflows": {
#           "Loan Application Processing": {
#             "Description": "Automated workflow for processing loan applications, including credit checks and approvals.",
#             "components": {
#               "Credit Scoring API": {},
#               "Loan Origination System": {}
#             }
#           },
#           "Fraud Detection": {
#             "Description": "Real-time monitoring and analysis of transactions to identify and prevent fraudulent activity.",
#             "components": {
#               "Transaction Monitoring System": {},
#               "Machine Learning Fraud Detection Model": {}
#             }
#           }
#         }
#       }
#     }
#   },
#   "Telecom": {
#     "companies": {
#       "Summit Communications": {
#         "workflows": {
#           "Network Provisioning": {
#             "Description": "Automated process for configuring and activating new network services for customers.",
#             "components": {
#               "Network Management System (NMS)": {},
#               "Service Activation API": {}
#             }
#           },
#           "Billing Cycle Processing": {
#             "Description": "Generates and distributes customer invoices based on usage data.",
#             "components": {
#               "Billing System": {},
#               "Rating Engine": {}
#             }
#           }
#         }
#       }
#     }
#   },
#   "Logistics & Supply Chain": {
#     "companies": {
#       "Global Transit Solutions": {
#         "workflows": {
#           "Shipment Tracking": {
#             "Description": "Provides real-time tracking information for shipments throughout the delivery process.",
#             "components": {
#               "GPS Tracking System": {},
#               "Shipment Visibility Portal": {}
#             }
#           },
#           "Warehouse Inventory Optimization": {
#             "Description": "Optimizes warehouse layout and inventory levels to minimize storage costs and improve order fulfillment speed.",
#             "components": {
#               "Warehouse Control System (WCS)": {},
#               "Demand Forecasting Engine": {}
#             }
#           }
#         }
#       }
#     }
#   }
# }
# ```

# %%
raw = response.text

# Remove BOM if present
raw = raw.lstrip("\ufeff")

# Remove markdown code fences if present
raw = re.sub(r"^```json\s*", "", raw)
raw = re.sub(r"^```\s*", "", raw)
raw = re.sub(r"\s*```$", "", raw)

raw = raw.strip()

data = json.loads(raw)

# %%
data_rows = []
for domain, domain_data in data.items():
    for company, company_data in domain_data["companies"].items():
        for workflow, workflow_data in company_data["workflows"].items():
            workflow_description = workflow_data["Description"]
            components = list(workflow_data["components"].keys())  # Extract component names
            
            # For each component, create a row
            for component in components:
                data_rows.append({
                    "Domain Name": domain,
                    "Company Name": company,
                    "Workflow Name": workflow,
                    "Workflow Description": workflow_description,
                    "Component Name": component
                })

# Convert the list of rows into a DataFrame
df = pd.DataFrame(data_rows)

# Display the DataFrame
print(df)
# Out:
#                  Domain Name              Company Name  \
# 0                 E-commerce          NovaRetail Group
# 1                 E-commerce          NovaRetail Group
# 2                 E-commerce          NovaRetail Group
# 3                 E-commerce          NovaRetail Group
# 4              Healthcare IT       Apex Health Systems
# 5              Healthcare IT       Apex Health Systems
# 6              Healthcare IT       Apex Health Systems
# 7              Healthcare IT       Apex Health Systems
# 8            Finance Systems   Veridian Financial Corp
# 9            Finance Systems   Veridian Financial Corp
# 10           Finance Systems   Veridian Financial Corp
# 11           Finance Systems   Veridian Financial Corp
# 12                   Telecom     Summit Communications
# 13                   Telecom     Summit Communications
# 14                   Telecom     Summit Communications
# 15                   Telecom     Summit Communications
# 16  Logistics & Supply Chain  Global Transit Solutions
# 17  Logistics & Supply Chain  Global Transit Solutions
# 18  Logistics & Supply Chain  Global Transit Solutions
# 19  Logistics & Supply Chain  Global Transit Solutions
#
#                         Workflow Name  \
# 0                   Order Fulfillment
# 1                   Order Fulfillment
# 2                  Returns Processing
# 3                  Returns Processing
# 4      Patient Appointment Scheduling
# 5      Patient Appointment Scheduling
# 6   Medical Image Storage & Retrieval
# 7   Medical Image Storage & Retrieval
# 8         Loan Application Processing
# 9         Loan Application Processing
# 10                    Fraud Detection
# 11                    Fraud Detection
# 12               Network Provisioning
# 13               Network Provisioning
# 14           Billing Cycle Processing
# 15           Billing Cycle Processing
# 16                  Shipment Tracking
# 17                  Shipment Tracking
# 18   Warehouse Inventory Optimization
# 19   Warehouse Inventory Optimization
#
#                                  Workflow Description  \
# 0   Automated process for receiving, processing, a...
# 1   Automated process for receiving, processing, a...
# 2   Handles customer returns, including authorizat...
# 3   Handles customer returns, including authorizat...
# 4   Manages patient appointment booking, reminders...
# 5   Manages patient appointment booking, reminders...
# 6   Securely stores and provides access to medical...
# 7   Securely stores and provides access to medical...
# 8   Automated workflow for processing loan applica...
# 9   Automated workflow for processing loan applica...
# 10  Real-time monitoring and analysis of transacti...
# 11  Real-time monitoring and analysis of transacti...
# 12  Automated process for configuring and activati...
# 13  Automated process for configuring and activati...
# 14  Generates and distributes customer invoices ba...
# 15  Generates and distributes customer invoices ba...
# 16  Provides real-time tracking information for sh...
# 17  Provides real-time tracking information for sh...
# 18  Optimizes warehouse layout and inventory level...
# 19  Optimizes warehouse layout and inventory level...
#
#                                        Component Name
# 0                         Inventory Management System
# 1                              Shipping Logistics API
# 2                         Return Authorization Portal
# 3                         Warehouse Management System
# 4          Electronic Health Record (EHR) Integration
# 5                       Appointment Scheduling Engine
# 6   PACS (Picture Archiving and Communication System)
# 7                           Image Viewing Workstation
# 8                                  Credit Scoring API
# 9                             Loan Origination System
# 10                      Transaction Monitoring System
# 11             Machine Learning Fraud Detection Model
# 12                    Network Management System (NMS)
# 13                             Service Activation API
# 14                                     Billing System
# 15                                      Rating Engine
# 16                                GPS Tracking System
# 17                         Shipment Visibility Portal
# 18                     Warehouse Control System (WCS)
# 19                          Demand Forecasting Engine

# %%
random_rows = df.sample(n=10, random_state=42)

for row in random_rows.to_dict('records'):
    prompt_ticket=f"""You are generating  realistic customer support ticket for an enterprise system.
        
        
    CONTEXT:
    - Domain: {row['Domain Name']}  (e.g., E-commerce, CRM)
    - Company Name: {row['Company Name']}  (e.g., Retail, Telecom)
    - Workflow Description: {row['Workflow Description']} 
    - Workflow: {row['Workflow Name']}  (e.g., Checkout, Payment Processing)
    - component: {row['Component Name']}  (e.g., Payment Gateway, User Management)
        
    TASK:
    -Write a natural-language support ticket describing the issue. 
    -The ticket text should sound like a real user complaint. 
    - Vary writing style, length, and tone.
    -The tone, language, and level of detail should reflect the user's expertise:
    A novice user will use simple language and ask for more guidance.
    An expert will use more technical terms and might ask more specific questions.
        
    Do NOT mention the system type, industry, workflow, or issue category in the ticket text.
    Give a description to the issue from 1 to 3 sentences
        
        
    OUTPUT:
    in VALID JSON FORMAT 
    -Return ticket text in natural language, without any additional explanation or metadata.
    -Affected component
    -severity of the problem"""


    response2 = model.generate_content(prompt_ticket)
    print(response2.text or "[EMPTY RESPONSE]")
# Out:
# ```json
# {
#   "ticket_text": "We're seeing a really strange discrepancy with stock levels. The system is showing we have 15 units of the 'Deluxe Coffee Maker' in stock, but when we try to fulfill orders, it keeps telling us we're out. We've manually checked the warehouse and confirmed we have at least 20, so something's clearly wrong with the numbers being reported.",
#   "affected_component": "Inventory Management System",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "I'm trying to track a shipment using the tracking number XYZ123456789, but the portal keeps showing 'Data unavailable'. I've refreshed the page multiple times and double-checked the tracking number, so I'm pretty sure it's entered correctly. Is there a known issue with the system, or am I missing something?",
#   "affected_component": "Shipment Visibility Portal",
#   "severity": "Medium"
# }
# ```
# ```json
# {
#   "ticket_text": "Hi, I'm seeing some really strange discrepancies in the invoices generated for several of our business clients this month. The charges don't seem to align with their reported usage, and I've checked the data feeds multiple times to ensure accuracy. Can someone please take a look at this and advise on how to troubleshoot the rating calculations?",
#   "affected_component": "Rating Engine",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "We're seeing a significant delay in shipping confirmations being sent to customers for orders placed yesterday. The tracking numbers are generated correctly within our system, but the Shipping Logistics API isn't pushing them to our email service provider. Can you investigate why these confirmations aren't being triggered?",
#   "affected_component": "Shipping Logistics API",
#   "severity": "high"
# }
# ```
# ```json
# {
#   "ticket_text": "We're seeing inconsistent credit scores being returned for applicants with identical profiles. I've run several tests with the same data – income, employment history, credit utilization – and the API is returning different scores each time, sometimes significantly. This is obviously impacting our ability to make consistent lending decisions and is causing delays in the approval process.",
#   "affected_component": "Credit Scoring API",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "We're seeing a really strange behavior with recurring appointments. When I try to reschedule a recurring series, only the first instance updates, and the rest remain on the original schedule. I've tried it with different providers and appointment types, and it consistently fails. Is there a known issue with the recurring logic, or am I missing something?",
#   "affected_component": "Appointment Scheduling Engine",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "The model's been flagging a lot of legitimate transactions as suspicious lately, specifically those over $5000. We've seen a spike in false positives impacting several high-value clients, and it's starting to cause significant delays in processing. Can we look into recalibrating the sensitivity threshold or investigating potential data drift?",
#   "affected_component": "Machine Learning Fraud Detection Model",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "I'm trying to process a return for order #789456, and the system is giving me an error when I try to update the 'Inspection Status' to 'Approved for Refund.' It just keeps looping back to the inspection screen. I've tried refreshing the page and logging out and back in, but nothing seems to work. Can someone please take a look?",
#   "affected_component": "Warehouse Management System",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "We're seeing some really strange behavior with the zone assignments. Items designated for Zone 3 are consistently being routed to Zone 5, even after multiple re-optimizations. This is causing significant bottlenecks in picking and fulfillment, and I'm concerned it's going to impact our ability to meet promised delivery times. Can someone take a look at the routing logic for Zone 3 and see if there's a configuration error?",
#   "affected_component": "Warehouse Control System (WCS)",
#   "severity": "High"
# }
# ```
# ```json
# {
#   "ticket_text": "The location data for shipment ID GT-78945-XZ is showing a completely unrealistic position – it's currently reporting as being in the middle of the Atlantic Ocean! This has been happening for the last three hours, and I've refreshed the dashboard multiple times. Can you please investigate and let me know what's going on?",
#   "affected_component": "GPS Tracking System",
#   "severity": "high"
# }
# ```

# %%
print(random_rows)
# Out:
#                  Domain Name              Company Name  \
# 0                 E-commerce          NovaRetail Group
# 17  Logistics & Supply Chain  Global Transit Solutions
# 15                   Telecom     Summit Communications
# 1                 E-commerce          NovaRetail Group
# 8            Finance Systems   Veridian Financial Corp
# 5              Healthcare IT       Apex Health Systems
# 11           Finance Systems   Veridian Financial Corp
# 3                 E-commerce          NovaRetail Group
# 18  Logistics & Supply Chain  Global Transit Solutions
# 16  Logistics & Supply Chain  Global Transit Solutions
#
#                        Workflow Name  \
# 0                  Order Fulfillment
# 17                 Shipment Tracking
# 15          Billing Cycle Processing
# 1                  Order Fulfillment
# 8        Loan Application Processing
# 5     Patient Appointment Scheduling
# 11                   Fraud Detection
# 3                 Returns Processing
# 18  Warehouse Inventory Optimization
# 16                 Shipment Tracking
#
#                                  Workflow Description  \
# 0   Automated process for receiving, processing, a...
# 17  Provides real-time tracking information for sh...
# 15  Generates and distributes customer invoices ba...
# 1   Automated process for receiving, processing, a...
# 8   Automated workflow for processing loan applica...
# 5   Manages patient appointment booking, reminders...
# 11  Real-time monitoring and analysis of transacti...
# 3   Handles customer returns, including authorizat...
# 18  Optimizes warehouse layout and inventory level...
# 16  Provides real-time tracking information for sh...
#
#                             Component Name
# 0              Inventory Management System
# 17              Shipment Visibility Portal
# 15                           Rating Engine
# 1                   Shipping Logistics API
# 8                       Credit Scoring API
# 5            Appointment Scheduling Engine
# 11  Machine Learning Fraud Detection Model
# 3              Warehouse Management System
# 18          Warehouse Control System (WCS)
# 16                     GPS Tracking System
